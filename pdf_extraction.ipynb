# %%
from pdf_reader import Reader
pdf_reader = Reader(path='Yo, robot - Isaac Asimov.pdf', reading_freq=0.5)
pdf_reader.read()
# Out:
# U
# n
# a
#
# i
# n
# v
# e
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from pdf_reader import Reader
#       2 pdf_reader = Reader(path='Yo, robot - Isaac Asimov.pdf', reading_freq=0.5)
# ----> 3 pdf_reader.read()
#
# File ~/Documentos/pdf-to-braille/pdf_reader.py:56, in Reader.read(self)
#      53 read_thread.start()
#      55 while read_thread.is_alive():
# ---> 56     if keyboard.is_pressed('q'):
#      57         self.stop_reading = True
#      58         read_thread.join()
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/__init__.py:410, in is_pressed(hotkey)
#     402 def is_pressed(hotkey):
#     403     """
#     404     Returns True if the key is pressed.
#     405
#    (...)
#     408         is_pressed('ctrl+space') #-> True
#     409     """
# --> 410     _listener.start_if_necessary()
#     412     if _is_number(hotkey):
#     413         # Shortcut.
#     414         with _pressed_events_lock:
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/_generic.py:35, in GenericListener.start_if_necessary(self)
#      33 try:
#      34     if not self.listening:
# ---> 35         self.init()
#      37         self.listening = True
#      38         self.listening_thread = Thread(target=self.listen)
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/__init__.py:196, in _KeyboardListener.init(self)
#     195 def init(self):
# --> 196     _os_keyboard.init()
#     198     self.active_modifiers = set()
#     199     self.blocking_hooks = []
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/_nixkeyboard.py:113, in init()
#     112 def init():
# --> 113     build_device()
#     114     build_tables()
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/_nixkeyboard.py:109, in build_device()
#     107 global device
#     108 if device: return
# --> 109 ensure_root()
#     110 device = aggregate_devices('kbd')
#
# File ~/.conda/envs/IT/lib/python3.12/site-packages/keyboard/_nixcommon.py:174, in ensure_root()
#     172 def ensure_root():
#     173     if os.geteuid() != 0:
# --> 174         raise ImportError('You must be root to use this library on linux.')
#
# ImportError: You must be root to use this library on linux.
# s
# t
# i
# g
# a
# c
# i
# ó
# n
#
# l
# l
# e
# v
# a
# d
# a
#
# a
#
# c
# a
# b
# o
#
# p
# o
# r
#
# u
# n
#
# p
# e
# r
# i
# o
# d
# i
# s
# t
# a
#
# a
# c
# e
# r
# c
# a
#
# d
# e
#
# l
# a
#
#
# t
# r
# a
# y
# e
# c
# t
# o
# r
# i
# a
#
# d
# e
#
# l
# a
#
# r
# o
# b
# o
# p
# s
# i
# c
# ó
# l
# o
# g
# a
#
# S
# u
# s
# a
# n
#
# C
# a
# l
# v
# i
# n
#
# d
# a
#
# p
# i
# e
#
# a
#
# l
# o
# s
#
# n
# u
# e
# v
# e
#
# r
# e
# l
# a
# t
# o
# s
#
#
# q
# u
# e
#
# c
# o
# m
# p
# o
# n
# e
# n
#
# e
# s
# t
# a
#
# n
# o
# v
# e
# l
# a
# .
#
# L
# a
# s
#
# t
# r
# e
# s
#
# l
# e
# y
# e
# s
#
# d
# e
#
# l
# a
#
# r
# o
# b
# ó
# t
# i
# c
# a
# ,
#
# a
#
# l
# a
# s
#
# q
# u
# e
#
# e
# n
#
#
# o
# b
# r
# a
# s
#
# p
# o
# s
# t
# e
# r
# i
# o
# r
# e
# s
#
# A
# s
# i
# m
# o
# v
#
# a
# ñ
# a
# d
# i
# r
# í
# a
#
# a
# l
# g
# u
# n
# a
#
# m
# á
# s
# ,
#
# c
# o
# n
# s
# t
# i
# t
# u
# y
# e
# n
#
# l
# a
# s
#
# n
# o
# r
# m
# a
# s
#
#
# q
# u
# e
#
# r
# i
# g
# e
# n
#
# e
# l
#
# c
# o
# m
# p
# o
# r
# t
# a
# m
# i
# e
# n
# t
# o
#
# e
# n
#
# l
# o
# s
#
# d
# i
# f
# e
# r
# e
# n
# t
# e
# s
#
# c
# o
# n
# f
# l
# i
# c
# t
# o
# s
#
# q
# u
# e
#
# s
# e
#
#
# p
# r
# e
# s
# e
# n
# t
# a
# n
#
# e
# n
# t
# r
# e
#
# h
# u
# m
# a
# n
# o
# s
#
# y
#
# r
# o
# b
# o
# t
# s
# .
#
# S
# i
#
# b
# i
# e
# n

# %%
import pymupdf
from time import time
from pdf_reader import Reader

pdf = pymupdf.open('Yo, robot - Isaac Asimov.pdf')
page_num = 13

titles = pdf.get_toc()
page_count = pdf.page_count

blocks = [block[4] for block in pdf[page_num].get_text('blocks')]

links = pdf[page_num].get_links()

page_text = pdf[page_num].get_text('text')
words = pdf[page_num].get_text('words')

annotations = pdf[page_num].annots()

widgets = pdf[page_num].widgets()
image = pdf[page_num].get_pixmap()
