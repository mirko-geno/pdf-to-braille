# %%
# %%capture
#!conda install PyMuPDF -y
import pymupdf

'''from google.colab import drive
drive.mount('/content/drive')'''

# %%
import pymupdf
from time import time, sleep

# %%
class PDF_Reader:
    def __init__(self, path, reading_speed):
        self.pdf = pymupdf.open(path)
        self.reading_speed = reading_speed
        self.titles = self.pdf.get_toc()
        self.page_count = self.pdf.page_count

'''    def page_data(self, page_num):
        links = self.pdf[page_num].get_links()
        page_text = self.pdf[page_num].get_text('text')
        blocks = self.pdf[page_num].get_text('blocks')
        words = self.pdf[page_num].get_text('words')
        annotations = self.pdf[page_num].annots()
        widgets = self.pdf[page_num].widgets()
        image = self.pdf[page_num].get_pixmap()

        return links, page_text, blocks, words, annotations, widgets, image'''

    def advance(self):
        for block_i, block in enumerate(blocks):
            for word_i, word in enumerate(block[4]):
                for letter in word:
                    reg_time = time() # yo  no
                    print(letter)
                    while reg_time + 1/reading_speed > time():pass

    def read(self):
        self.__page_i = 0
        self.__block_i = 0
        self.__word_i = 0
        reg_time = time()
        while reg_time + 1/reading_speed > time() and page_num<page_count:
            reg_time = time()
            if
        for block_i, block in enumerate(blocks):
            for word_i, word in enumerate(block[4]):
                for letter in word:
                    reg_time = time() # yo  no
                    print(letter)
                    while reg_time + 1/reading_speed > time():pass

# %%
pdf = pymupdf.open('Yo, robot - Isaac Asimov.pdf')

titles = pdf.get_toc()
page_count = pdf.page_count

# %%
page_num = 13

links = pdf[page_num].get_links()

page_text = pdf[page_num].get_text('text')
blocks = pdf[page_num].get_text('blocks')
words = pdf[page_num].get_text('words')

annotations = pdf[page_num].annots()

widgets = pdf[page_num].widgets()
image = pdf[page_num].get_pixmap()

# %%
reading_speed = 2 #Letters per second
reg_time = time()

for block_i, block in enumerate(blocks):
    for word_i, word in enumerate(block[4]):
        for letter in word:
            reg_time = time() # yo  no
            print(letter)
            while reg_time + 1/reading_speed > time():pass

# %%
actual = time.time()
while actual + 5 > time.time():
    print('hola')
    time.sleep(0.5)
# Out:
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
# hola
